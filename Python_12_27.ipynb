# %% [markdown]
# <img src="https://docs.google.com/uc?id=14xeXxFrVRjvOoUYWn_GuyE-v84wVzrqr" class="img-fluid" alt="CLRWY" width="400" height="200">

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#0D8D99; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Python Session-12 (27 Oct 2022)</p>

# %% [markdown]
# ### <div class="alert alert-block alert-info"><h1><p style="text-align: center; color:purple"> Comparision Operators<br><br>IF ELSE Statements<br><br>Nested IF ELSE Statements</p>

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Comparision Operators</p>

# %% [markdown]
# **Python official documentation - Comparisions: https://docs.python.org/3/reference/expressions.html#comparisons**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
1 == 1
# Out:
# True

# %%
3 > 3
# Out:
# False

# %%
3 >= 3
# Out:
# True

# %%
3 >= 2
# Out:
# True

# %%
"apple" == "apple"
# Out:
# True

# %%
"apple" == "Apple"
# Out:
# False

# %%
"apple" != "orange"
# Out:
# True

# %%
"apple" != "apple"
# Out:
# False

# %%
"apple" < "orange"
# Out:
# True

# %%
"banana" < "apple"
# Out:
# False

# %%
"ali" == "deli"
# Out:
# False

# %%
"ali" != "deli"
# Out:
# True

# %%
if "ali" != "deli" :
    print("veli")
# Out:
# veli

# %%
x = 5

y = 15

# %%
x < y
# Out:
# True

# %%
y < x
# Out:
# False

# %%
set1 = set("TWELVE PLUS ONE")

set2 = set("ELEVEN PLUSU TWO")

set1 == set2
# Out:
# True

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">IF - ELIF - ELSE Statements</p>

# %% [markdown]
# **Python official documentation - IF Statements: https://docs.python.org/3/tutorial/controlflow.html**

# %% [markdown]
# **IF - ELSE Statement Syntax :**
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-3.png](attachment:image-3.png)

# %%
set1 = set("TWELVE PLUS ONE")

set2 = set("ELEVEN PLUSU TWO")

if set1 == set2 :
    print("We are the same!")
# Out:
# We are the same!

# %%
if 1 and "bir" and [] :
    print("if bloğu çalıştı")
    
print("if bloğu çalışmadı")
# Out:
# if bloğu çalışmadı

# %%
1 and "bir" and (1,)
# Out:
# (1,)

# %%
if 1 and (1,) and "bir":
    print("if bloğu çalıştı")
    
print("bu her halükarda çalışır")
# Out:
# if bloğu çalıştı
# bu her halükarda çalışır

# %%
if "ali" == "Ali" :
    print("deli")

# %%
type(input("bir şey yaz :"))
# Out:
# bir şey yaz :alideliveli
# str

# %%
type(input("bir rakam yaz :"))
# Out:
# bir rakam yaz :11
# str

# %%
type(int(input("bir rakam yaz :")))
# Out:
# bir rakam yaz :11
# int

# %% [markdown]
# **Task:**

# %%
convert = input("Yes veya No giriniz :").title()
# Out:
# Yes veya No giriniz :Yes

# %%
convert
# Out:
# 'Yes'

# %%
convert = input("Yes veya No giriniz :").title().strip() == "Yes"

convert
# Out:
# Yes veya No giriniz :no
# False

# %%
convert = input("Yes veya No giriniz :").lower().strip() == "yes"

convert

# %%
print(f"You entered {convert}")
# Out:
# You entered False

# %%
print(f"You entered {input("Yes veya No giriniz :").lower().strip() == "yes"}")
# Out:
#   Input In [6]
#     print(f"You entered {input("Yes veya No giriniz :").lower().strip() == "yes"}")
#                                 ^
# SyntaxError: f-string: unmatched '('

# %%
print(f'You entered {input("Yes veya No giriniz :").lower().strip() == "yes"}')
# Out:
# Yes veya No giriniz :YES
# You entered True

# %%
x = 5

# %%
if x >= 6 :
    print("hello")
else :
    print("world")
# Out:
# world

# %%
x = list(range(1, 10))
x
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
if 10 in x :
    print("hello")
else:
    print("world")
# Out:
# world

# %% [markdown]
# **Task:**

# %%
num = int(input("Enter a number :"))

if num % 2 == 0 :
    print("{} is even".format(num))
else :
    print("{} is od**Task:**d".format(num))
# Out:
# Enter a number :-11
# -11 is odd

# %% [markdown]
# **Task:**

# %%
num = float(input("enter a number except zero :"))

if num > 0 :
    print("is is a positive number.")
    
else :
    print("it is a negative number.")
# Out:
# enter a number except zero :-8
# it is a negative number.

# %% [markdown]
# **Task:**

# %%
num1 = float(input("enter first number :"))

num2 = float(input("enter second number :"))

if num1 > num2 :
    larger = num1
    
else :
    larger = num2
    
print("the larger number is : ", larger)
# Out:
# enter first number :4
# enter second number :9
# the larger number is :  9.0

# %% [markdown]
# **Task:**

# %%
bool_value = True

if bool_value :
    print("Yes")

else :
    print("No")
# Out:
# Yes

# %%
"a" < "b"
# Out:
# True

# %%
"b" < "a"
# Out:
# False

# %% [markdown]
# **Task:**

# %%
num1 = float(input("Enter first number :"))
num2 = float(input("Enter first number :"))
num3 = float(input("Enter first number :"))

if (num1 >= num2) and (num1 >= num3) :
    largest = num1
elif (num2 >= num1) and (num2 >= num3) :
    largest = num2
else :
    largest = num3
print("The largest number is", largest)
# Out:
# Enter first number :6
# Enter first number :7
# Enter first number :1
# The largest number is 7.0

# %% [markdown]
# **Task:**

# %%
num = int(input("enter a number :"))

if num > 0 :**Task:**
    print("positive number")

elif num == 0 :
    print("zero")

else :
    print("negative")
# Out:
# enter a number :9
# positive number

# %% [markdown]
# <a id="toc"></a>
#
# ## <p style="background-color:#9d4f8c; font-family:newtimeroman; color:#FFF9ED; font-size:175%; text-align:center; border-radius:10px 10px;">Nested IF - ELIF - ELSE Statements</p>

# %% [markdown]
# **Link 1 - If elif else / Nested if elif else: https://www.geeksforgeeks.org/python3-if-if-else-nested-if-if-elif-statements/**
#
# **Link 2 : https://pythongeeks.org/python-if-else-if-elif-nested-if-else-decision-making-in-python/**

# %% [markdown]
# **Task:**

# %%
audience**Task:** = "baby"

if audience == "kid" :
    print("it is free to go to cinema")
elif audience == "teen":
    print("discounted price!")
elif audience == "adult":
    print("normal price")
else:
    print("No such audience, stay at your home!")
# Out:
# No such audience, stay at your home!

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Task:**

# %%
score = int(input("Enter your score :"))

if score >= 90 :
    if score >= 95 :
        score_letter = "A+"
    else :
        score_letter = "A"
        
elif score >= 80 :
    if score >= 85 :
        score_letter = "B+"
    else :
        score_letter = "B"

else :
    score_letter = "B-"
    
print("Your degree is : ", score_letter)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <img src="https://docs.google.com/uc?id=14xeXxFrVRjvOoUYWn_GuyE-v84wVzrqr" class="img-fluid" alt="CLRWY" width="400" height="200">
